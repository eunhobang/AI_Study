# %% [markdown]
# <a href="https://colab.research.google.com/github/eunhobang/AI_Study/blob/main/8_8_bt4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 웹페이지 구조

# %%
# %%writefile example.html
# <!DOCTYPE html>
# <html>
#   <head>
#     <title> Page Title </title>
#   </head>
#   <body>
#     <h1> Heading </h1>
#     <p> Paragraph </p>
#     <div>
#       <a href = "www.google.com"> google </a>
#     </div>
#     <div class = "class1">
#       <p> a </p>
#       <a href = "www.naver.com"> naver </a>
#       <p> b </p>
#       <p> c </p>
#     </div>
#     <div id = "id1">
#       Example page
#       <p> g </p>
#     </div>
#   </body>
# </html>
# Out:
# Writing example.html

# %%
from bs4 import BeautifulSoup
import urllib.request

with open("example.html") as fp:
  soup = BeautifulSoup(fp, 'html.parser') # html.parser이용해서 전체파일 보기

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title> Page Title </title>
# </head>
# <body>
# <h1> Heading </h1>
# <p> Paragraph </p>
# <div>
# <a href="www.google.com"> google </a>
# </div>
# <div class="class1">
# <p> a </p>
# <a href="www.naver.com"> naver </a>
# <p> b </p>
# <p> c </p>
# </div>
# <div id="id1">
#       Example page
#       <p> g </p>
# </div>
# </body>
# </html>

# %% [markdown]
# # HTML 태크 파싱

# %%
soup.title
# Out:
# <title> Page Title </title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.string
# Out:
# ' Page Title '

# %%
soup.title.parent
# Out:
# <head>
# <title> Page Title </title>
# </head>

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
soup.h1
# Out:
# <h1> Heading </h1>

# %%
soup.p
# Out:
# <p> Paragraph </p>

# %%
soup.div
# Out:
# <div>
# <a href="www.google.com"> google </a>
# </div>

# %%
soup.a
# Out:
# <a href="www.google.com"> google </a>

# %% [markdown]
# # HTML 태그 검색
#
# - find(): 해당 조건에 맞는 하나의 태그를 가져옴
# - find_all(): 해당 조건에 맞는 모든 태크를 가져옴
# - select(): CSS 서냍작와 같은 형식으로 선택 가능

# %%
soup_find_all = soup.find_all("div")
soup_find_all
# Out:
# [<div>
#  <a href="www.google.com"> google </a>
#  </div>, <div class="class1">
#  <p> a </p>
#  <a href="www.naver.com"> naver </a>
#  <p> b </p>
#  <p> c </p>
#  </div>, <div id="id1">
#        Example page
#        <p> g </p>
#  </div>]

# %%
find_by_id = soup.find_all('div',{'id':'id1'})
print(find_by_id)
# Out:
# [<div id="id1">
#       Example page
#       <p> g </p>
# </div>]

# %%
find_by_class = soup.find_all('div',{'class':'class1'})
print(find_by_class)
# Out:
# [<div class="class1">
# <p> a </p>
# <a href="www.naver.com"> naver </a>
# <p> b </p>
# <p> c </p>
# </div>]

# %%
# %%writefile anthem.html
# <!DOCTYPE html>
# <html>
#   <head>
#     <title> Page Title </title>
#   </head>
#   <body>
#     <div>
#       <p id = 'title'> 애국가 </p>
#       <p id = 'content'>
#         동해물과 백두산이 마르고 닳도록 하느님이 보우하사 우리나라 만세 <br />
#         무궁화 삼천리 화려 강산 대한 사람, 대한으로 길이 보전하세 <br />
#       </p>
#       <p id = 'content'>
#         남산 위에 저 소나무, 철값을 두른 듯 바람 서리 불변함은 우리 기상일세  <br />
#         무궁화 삼천리 화려 강산 대한 사람, 대한으로 길이 보전하세 <br />
#       </p>
#       <p id = 'content'>
#         가을 하늘 공할한데 높고 구름 없이 밝은 달은 우리 가슴 일편단심일세 <br />
#         무궁화 삼천리 화려 강산 대한 사람, 대한으로 길이 보전하세 <br />
#       </p>
#       <p id = 'content'>
#         이 기상과 이 맘으로 충성을 다하여 괴로우나 즐거우나 나라 사랑하세 <br />
#         무궁화 삼천리 화려 강산 대한 사람, 대한으로 길이 보전하세 <br />
#       </p>
#     </div>
#   </body>
# </html>
# Out:
# Writing anthem.html

# %%
with open("anthem.html") as fp:
  soup = BeautifulSoup(fp, 'html.parser') #parser 무조건 해야 됨


soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title> Page Title </title>
# </head>
# <body>
# <div>
# <p id="title"> 애국가 </p>
# <p id="content">
#         동해물과 백두산이 마르고 닳도록 하느님이 보우하사 우리나라 만세 <br/>
#         무궁화 삼천리 화려 강산 대한 사람, 대한으로 길이 보전하세 <br/>
# </p>
# <p id="content">
#         남산 위에 저 소나무, 철값을 두른 듯 바람 서리 불변함은 우리 기상일세  <br/>
#         무궁화 삼천리 화려 강산 대한 사람, 대한으로 길이 보전하세 <br/>
# </p>
# <p id="content">
#         가을 하늘 공할한데 높고 구름 없이 밝은 달은 우리 가슴 일편단심일세 <br/>
#         무궁화 삼천리 화려 강산 대한 사람, 대한으로 길이 보전하세 <br/>
# </p>
# <p id="content">
#         이 기상과 이 맘으로 충성을 다하여 괴로우나 즐거우나 나라 사랑하세 <br/>
#         무궁화 삼천리 화려 강산 대한 사람, 대한으로 길이 보전하세 <br/>
# </p>
# </div>
# </body>
# </html>

# %%
title = soup.find('p', {'id': 'title'})
contents = soup.find_all('p', {'id': 'content'})

print(title.get_text())

for content in contents:
  print(content.get_text())
# Out:
#  애국가
#
#         동해물과 백두산이 마르고 닳도록 하느님이 보우하사 우리나라 만세
#         무궁화 삼천리 화려 강산 대한 사람, 대한으로 길이 보전하세
#
#
#         남산 위에 저 소나무, 철값을 두른 듯 바람 서리 불변함은 우리 기상일세
#         무궁화 삼천리 화려 강산 대한 사람, 대한으로 길이 보전하세
#
#
#         가을 하늘 공할한데 높고 구름 없이 밝은 달은 우리 가슴 일편단심일세
#         무궁화 삼천리 화려 강산 대한 사람, 대한으로 길이 보전하세
#
#
#         이 기상과 이 맘으로 충성을 다하여 괴로우나 즐거우나 나라 사랑하세
#         무궁화 삼천리 화려 강산 대한 사람, 대한으로 길이 보전하세

# %% [markdown]
# # 인터넷 웹페이지 가져오기

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

res_comic = requests.get('https://comic.naver.com/index')
soup_comic = BeautifulSoup(res_comic.text, 'lxml')

soup_comic
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <title>네이버 웹툰</title>
# <meta content="네이버 웹툰" property="og:title"/>
# <meta content="https://ssl.pstatic.net/static/comic/images/og_tag_v2.png" property="og:image"/>
# <meta content="매일매일 새로운 재미, 네이버 웹툰." property="og:description"/>
# <meta content="https://comic.naver.com/index" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="네이버 웹툰" property="og:article:author"/>
# <meta content="https://comic.naver.com" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/static/comic/favicon/webtoon_favicon_32x32.ico" rel="shortcut icon" type="image/x-icon"/>
# ...

# %% [markdown]
# # 네이버 웹툰 인기순위 웹스크래핑

# %%
#정적 웹페이지 데이터 가져오기
#태그 찾기 편리한 모듈, 서버 접속을 위한 라이브러리, 데이터프레임을 만들기 위한 라이브러리
from bs4 import BeautifulSoup
import requests
import pandas as pd

res_comic = requests.get('https://comic.naver.com/index')
soup_comic = BeautifulSoup(res_comic.text, 'lxml')

comic_all = soup_comic.find("ol", attrs = {"id":"realTimeRankFavorite"}).find_all("li")

list_comic_all = []
for rank, comic in enumerate(comic_all):
  list_comic = []
  list_comic.append(rank + 1)
  list_comic.append(comic.a.text.strip())
  list_comic.append('https://comic.naver.com' + comic.a['href'])
  list_comic_all.append(list_comic)
  
df_comic = pd.DataFrame(list_comic_all, columns = ['순위', '제목', '링크'])

df_comic
# Out:
#    순위                        제목  \
# 0   1                   참교육-92화
# 1   2     퀘스트지상주의-42화 묘한 매력이 있어
# 2   3  윈드브레이커-4부 - 22화 남성춘과 조마현
# 3   4            소녀의 세계-2부 112화
# 4   5            백수세끼-138화 소갈비살
# 5   6              신의 탑-3부 132화
# 6   7   뷰티풀 군바리-340화_신임 중대장 (3)
# 7   8    신화급 귀속 아이템을 손에 넣었다-10화
# 8   9            장씨세가 호위무사-169화
# 9  10             팔이피플-43화 - 결심
#
#                                                   링크
# 0  https://comic.naver.com/webtoon/detail?titleId...
# 1  https://comic.naver.com/webtoon/detail?titleId...
# 2  https://comic.naver.com/webtoon/detail?titleId...
# 3  https://comic.naver.com/webtoon/detail?titleId...
# 4  https://comic.naver.com/webtoon/detail?titleId...
# 5  https://comic.naver.com/webtoon/detail?titleId...
# 6  https://comic.naver.com/webtoon/detail?titleId...
# 7  https://comic.naver.com/webtoon/detail?titleId...
# 8  https://comic.naver.com/webtoon/detail?titleId...
# 9  https://comic.naver.com/webtoon/detail?titleId...
